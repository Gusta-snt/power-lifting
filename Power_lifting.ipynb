# %%
import pandas as pd

power_lifting = pd.read_csv("powerlifting.csv")

power_lifting
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# ...              ...  ...          ...          ...                 ...
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
# 2997    Sarah Thomas   62         Open        Squat                 148
# 2998     Chris Brown   32        93 kg  Bench Press                 333
# 2999      Daniel Lee   22        83 kg     Deadlift                 280
#
# [3000 rows x 5 columns]

# %%
exercicios = power_lifting["Lift Type"].unique().tolist()

# %%
for exercicio in exercicios:
  media = power_lifting.loc[power_lifting["Lift Type"] == exercicio, "Amount Lifted (kg)"].mean()
  print(f"O exercício {exercicio} tem média de {round(media, 2)} kg")
# Out:
# O exercício Bench Press tem média de 255.69 kg
# O exercício Squat tem média de 246.56 kg
# O exercício Deadlift tem média de 248.59 kg

# %% [markdown]
# A idade afeta a quantidade de peso levantada?

# %%
idades = power_lifting["Age"].tolist()
quantidade_peso = power_lifting["Amount Lifted (kg)"].tolist()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='Age', y='Amount Lifted (kg)', data=power_lifting)
plt.show()

# %%
classes = power_lifting["Weight Class"].unique().tolist()

maior = 0
classe_maior = ""
for classe in classes:
  media = power_lifting.loc[power_lifting["Weight Class"] == classe, "Amount Lifted (kg)"].mean()
  if media > maior:
    maior = media
    classe_maior = classe

print(f"A classe que levanta mais quilos em média é {classe_maior}, levantando {round(float(maior), 2)} kg")
# Out:
# A classe que levanta mais quilos em média é 83 kg, levantando 254.57 kg

# %%
nomes = power_lifting["Lifter Name"].unique().tolist()
medias = []
for nome in nomes:
  media = power_lifting.loc[power_lifting["Lifter Name"] == nome, "Amount Lifted (kg)"].mean()
  medias.append(media)
  print(f"O levantador {nome} tem média de {round(media, 2)} kg")
# Out:
# O levantador Jessica Wilson tem média de 235.93 kg
# O levantador John Doe tem média de 246.03 kg
# O levantador Emily Davis tem média de 254.68 kg
# O levantador Laura Taylor tem média de 247.24 kg
# O levantador Sarah Thomas tem média de 255.25 kg
# O levantador Michael Johnson tem média de 246.05 kg
# O levantador Chris Brown tem média de 257.22 kg
# O levantador Daniel Lee tem média de 258.74 kg
# O levantador Matthew Anderson tem média de 254.47 kg
# O levantador Jane Smith tem média de 248.16 kg

# %%
plt.bar(nomes, medias)
plt.xticks(rotation=45, ha="right")
plt.show()
